# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishak-krishnan/Deep-Learning-Architectures/blob/main/DenseNet_169.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist, fashion_mnist, cifar10, cifar100
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd

# Data Loading and Preprocessing
def load_and_preprocess_data(dataset_name):
    if dataset_name == 'mnist':
        (x_train, y_train), (x_test, y_test) = mnist.load_data()
        x_train = x_train[..., tf.newaxis]
        x_test = x_test[..., tf.newaxis]
    elif dataset_name == 'fashion_mnist':
        (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
        x_train = x_train[..., tf.newaxis]
        x_test = x_test[..., tf.newaxis]
    elif dataset_name == 'cifar10':
        (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    elif dataset_name == 'cifar100':
        (x_train, y_train), (x_test, y_test) = cifar100.load_data()
    else:
        raise ValueError("Unknown dataset")

    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # Resize images to 32x32
    if dataset_name in ['mnist', 'fashion_mnist']:
        x_train = tf.image.resize(x_train, [32, 32])
        x_test = tf.image.resize(x_test, [32, 32])
        x_train = tf.image.grayscale_to_rgb(x_train)
        x_test = tf.image.grayscale_to_rgb(x_test)

    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    return x_train, y_train, x_test, y_test

# Define DenseNet-169 Model
def create_densenet169_model(input_shape, num_classes):
    base_model = DenseNet169(weights=None, include_top=False, input_shape=input_shape)
    x = base_model.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=base_model.input, outputs=x)
    return model

# Visualize Random Data Samples
def visualize_random_samples(x_data, y_data, num_classes, dataset_name):
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i+1)
        plt.imshow(x_data[i])
        plt.title(f"Label: {np.argmax(y_data[i])}")
        plt.axis('off')
    plt.suptitle(f"Random Samples from {dataset_name}")
    plt.show()

# Main Function
def main():
    datasets = ['mnist', 'fashion_mnist', 'cifar10', 'cifar100']
    metrics = []

    for dataset in datasets:
        print(f"\nStarting training for {dataset}...")

        # Load and preprocess data
        x_train, y_train, x_test, y_test = load_and_preprocess_data(dataset)
        num_classes = y_train.shape[1]
        input_shape = x_train.shape[1:]

        # Visualize random samples
        visualize_random_samples(x_train, y_train, num_classes, dataset)

        # Create and compile model
        model = create_densenet169_model(input_shape, num_classes)
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Train model
        history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

        # Evaluate and print results
        test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
        print(f"Test accuracy for {dataset}: {test_acc}")

        # Predict and compute metrics
        y_pred = model.predict(x_test)
        y_pred_classes = y_pred.argmax(axis=-1)
        y_true_classes = y_test.argmax(axis=-1)

        report = classification_report(y_true_classes, y_pred_classes, output_dict=True)
        precision = report['accuracy']
        recall = report['accuracy']
        f1_score = report['accuracy']
        loss = test_loss

        metrics.append({
            'Dataset': dataset,
            'Accuracy': test_acc,
            'Precision': precision,
            'Recall': recall,
            'F1 Score': f1_score,
            'Loss': loss
        })

        # Confusion Matrix
        cm = confusion_matrix(y_true_classes, y_pred_classes)
        plt.figure(figsize=(10, 7))
        sns.heatmap(cm, annot=True, fmt='d')
        plt.title(f'Confusion Matrix for {dataset}')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()

        print(f"Finished training for {dataset}.\n")

    # Create and display metrics table
    metrics_df = pd.DataFrame(metrics)
    print("Metrics Table:")
    print(metrics_df)

if __name__ == "__main__":
    main()
# Out:
# Starting training for mnist...
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 762s 455ms/step - accuracy: 0.8944 - loss: 0.3767 - val_accuracy: 0.9511 - val_loss: 0.1802
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 518s 345ms/step - accuracy: 0.9764 - loss: 0.0882 - val_accuracy: 0.9628 - val_loss: 0.1403
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 556s 370ms/step - accuracy: 0.9821 - loss: 0.0670 - val_accuracy: 0.9523 - val_loss: 0.1618
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 526s 350ms/step - accuracy: 0.9856 - loss: 0.0542 - val_accuracy: 0.9602 - val_loss: 0.1724
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 589s 393ms/step - accuracy: 0.9856 - loss: 0.0547 - val_accuracy: 0.9689 - val_loss: 0.1093
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 526s 350ms/step - accuracy: 0.9876 - loss: 0.0404 - val_accuracy: 0.9843 - val_loss: 0.0614
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 541s 361ms/step - accuracy: 0.9862 - loss: 0.0518 - val_accuracy: 0.9868 - val_loss: 0.0464
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 633s 422ms/step - accuracy: 0.9905 - loss: 0.0310 - val_accuracy: 0.9805 - val_loss: 0.0821
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 525s 350ms/step - accuracy: 0.9901 - loss: 0.0375 - val_accuracy: 0.9811 - val_loss: 0.0703
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 509s 339ms/step - accuracy: 0.9913 - loss: 0.0306 - val_accuracy: 0.9860 - val_loss: 0.0589
# 313/313 - 31s - 98ms/step - accuracy: 0.9858 - loss: 0.0602
# Test accuracy for mnist: 0.98580002784729
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 32s 88ms/step
# Finished training for mnist.
#
#
# Starting training for fashion_mnist...
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 646s 382ms/step - accuracy: 0.7403 - loss: 0.7578 - val_accuracy: 0.8707 - val_loss: 0.3562
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 556s 370ms/step - accuracy: 0.8642 - loss: 0.3757 - val_accuracy: 0.8612 - val_loss: 0.3620
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 557s 371ms/step - accuracy: 0.8822 - loss: 0.3235 - val_accuracy: 0.8700 - val_loss: 0.3475
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 556s 371ms/step - accuracy: 0.8947 - loss: 0.2869 - val_accuracy: 0.8801 - val_loss: 0.3227
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 554s 370ms/step - accuracy: 0.9009 - loss: 0.2707 - val_accuracy: 0.9034 - val_loss: 0.2665
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 552s 368ms/step - accuracy: 0.9133 - loss: 0.2400 - val_accuracy: 0.9030 - val_loss: 0.2736
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 553s 369ms/step - accuracy: 0.8989 - loss: 0.2924 - val_accuracy: 0.9019 - val_loss: 0.2756
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 546s 364ms/step - accuracy: 0.9210 - loss: 0.2128 - val_accuracy: 0.8798 - val_loss: 0.3413
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 542s 361ms/step - accuracy: 0.9229 - loss: 0.2046 - val_accuracy: 0.9103 - val_loss: 0.2519
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 542s 361ms/step - accuracy: 0.9317 - loss: 0.1874 - val_accuracy: 0.8986 - val_loss: 0.2827
# 313/313 - 29s - 92ms/step - accuracy: 0.8961 - loss: 0.2921
# Test accuracy for fashion_mnist: 0.8960999846458435
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 31s 86ms/step
# Finished training for fashion_mnist.
#
#
# Starting training for cifar10...
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 565s 394ms/step - accuracy: 0.3467 - loss: 1.8329 - val_accuracy: 0.3528 - val_loss: 1.9788
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 503s 402ms/step - accuracy: 0.5447 - loss: 1.2715 - val_accuracy: 0.4144 - val_loss: 1.7321
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 532s 425ms/step - accuracy: 0.6354 - loss: 1.0324 - val_accuracy: 0.5057 - val_loss: 1.5035
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 482s 385ms/step - accuracy: 0.6950 - loss: 0.8817 - val_accuracy: 0.5907 - val_loss: 1.2987
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 474s 379ms/step - accuracy: 0.7345 - loss: 0.7669 - val_accuracy: 0.6401 - val_loss: 1.0885
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 475s 380ms/step - accuracy: 0.7750 - loss: 0.6497 - val_accuracy: 0.6613 - val_loss: 1.0106
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 474s 379ms/step - accuracy: 0.8029 - loss: 0.5777 - val_accuracy: 0.6737 - val_loss: 1.0379
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 474s 379ms/step - accuracy: 0.8299 - loss: 0.4936 - val_accuracy: 0.6955 - val_loss: 0.9661
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 470s 376ms/step - accuracy: 0.8543 - loss: 0.4190 - val_accuracy: 0.7291 - val_loss: 0.8217
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 467s 374ms/step - accuracy: 0.8769 - loss: 0.3609 - val_accuracy: 0.7289 - val_loss: 0.8597
# 313/313 - 27s - 86ms/step - accuracy: 0.7335 - loss: 0.8651
# Test accuracy for cifar10: 0.7335000038146973
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 99ms/step
# Finished training for cifar10.
#
#
# Starting training for cifar100...
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 589s 413ms/step - accuracy: 0.0633 - loss: 4.2119 - val_accuracy: 0.1023 - val_loss: 3.9651
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 494s 395ms/step - accuracy: 0.1392 - loss: 3.6054 - val_accuracy: 0.1214 - val_loss: 4.3690
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 499s 399ms/step - accuracy: 0.1989 - loss: 3.2679 - val_accuracy: 0.0662 - val_loss: 5.1687
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 497s 397ms/step - accuracy: 0.2561 - loss: 2.9300 - val_accuracy: 0.2477 - val_loss: 2.9979
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 496s 397ms/step - accuracy: 0.3123 - loss: 2.6630 - val_accuracy: 0.2801 - val_loss: 2.8898
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 492s 394ms/step - accuracy: 0.3541 - loss: 2.4417 - val_accuracy: 0.2173 - val_loss: 3.5352
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 495s 396ms/step - accuracy: 0.3948 - loss: 2.2325 - val_accuracy: 0.2838 - val_loss: 2.9640
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 488s 391ms/step - accuracy: 0.4408 - loss: 2.0414 - val_accuracy: 0.3348 - val_loss: 2.6709
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 492s 393ms/step - accuracy: 0.4802 - loss: 1.8555 - val_accuracy: 0.3305 - val_loss: 2.8805
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 529s 423ms/step - accuracy: 0.5219 - loss: 1.6846 - val_accuracy: 0.3374 - val_loss: 2.7867
# 313/313 - 31s - 98ms/step - accuracy: 0.3500 - loss: 2.7597
# Test accuracy for cifar100: 0.3499999940395355
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 108ms/step
# Finished training for cifar100.
#
# Metrics Table:
#          Dataset  Accuracy  Precision  Recall  F1 Score      Loss
# 0          mnist    0.9858     0.9858  0.9858    0.9858  0.060246
# 1  fashion_mnist    0.8961     0.8961  0.8961    0.8961  0.292071
# 2        cifar10    0.7335     0.7335  0.7335    0.7335  0.865075
# 3       cifar100    0.3500     0.3500  0.3500    0.3500  2.759743
